# %% [markdown]
# ### Encoding
# 1. Nominal
# 2. Ordinal

# %%
import pandas as pd

# %%
df=pd.read_csv('HR_Attrition.csv')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome    Education EducationField  EmployeeCount  \
# 0                 1     Bachelor  Life Sciences              1
# 1                 8  High School  Life Sciences              1
# 2                 2     Bachelor          Other              1
# 3                 3          PhD  Life Sciences              1
# 4                 2  High School        Medical              1
#
#    EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0               1  ...                         1            80
# ...

# %%
df['BusinessTravel'].unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
for column in df:
    print(column, df[column].unique())
    print('----------')
# Out:
# Age [41 49 37 33 27 32 59 30 38 36 35 29 31 34 28 22 53 24 21 42 44 46 39 43
#  50 26 48 55 45 56 23 51 40 54 58 20 25 19 57 52 47 18 60]
# ----------
# Attrition ['Yes' 'No']
# ----------
# BusinessTravel ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# ----------
# DailyRate [1102  279 1373 1392  591 1005 1324 1358  216 1299  809  153  670 1346
#   103 1389  334 1123 1219  371  673 1218  419  391  699 1282 1125  691
#   477  705  924 1459  125  895  813 1273  869  890  852 1141  464 1240
#  1357  994  721 1360 1065  408 1211 1229  626 1434 1488 1097 1443  515
#   853 1142  655 1115  427  653  989 1435 1223  836 1195 1339  664  318
#  1225 1328 1082  548  132  746  776  193  397  945 1214  111  573 1153
#  1400  541  432  288  669  530  632 1334  638 1093 1217 1353  120  682
#   489  807  827  871  665 1040 1420  240 1280  534 1456  658  142 1127
#  1031 1189 1354 1467  922  394 1312  750  441  684  249  841  147  528
# ...

# %% [markdown]
# From the above rows, we identified the columns that will be encoded as nominal and ordinal
# Ordinal: WorkLifeBalance, RealationshipSatisfaction
# Nominal: All other categorical columns

# %%
one_hot_encoded = pd.get_dummies(df, columns=['Department'])
one_hot_encoded 
# Orignal column is removed and three new columns were created
# Out:
#       Age Attrition     BusinessTravel  DailyRate  DistanceFromHome  \
# 0      41       Yes      Travel_Rarely       1102                 1
# 1      49        No  Travel_Frequently        279                 8
# 2      37       Yes      Travel_Rarely       1373                 2
# 3      33        No  Travel_Frequently       1392                 3
# 4      27        No      Travel_Rarely        591                 2
# ...   ...       ...                ...        ...               ...
# 1465   36        No  Travel_Frequently        884                23
# 1466   39        No      Travel_Rarely        613                 6
# 1467   27        No      Travel_Rarely        155                 4
# 1468   49        No  Travel_Frequently       1023                 2
# 1469   34        No      Travel_Rarely        628                 8
#
#         Education EducationField  EmployeeCount  EmployeeNumber  \
# 0        Bachelor  Life Sciences              1               1
# ...

# %% [markdown]
# ### Label/ Ordinal encoding

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
encoder = OrdinalEncoder()
education_reshaped = df['Education'].values.reshape(-1,1)
df['Education_encoded']=encoder.fit_transform(education_reshaped)
df[['Education_encoded','Education']].head(n=10)
# Out:
#    Education_encoded    Education
# 0                0.0     Bachelor
# 1                1.0  High School
# 2                0.0     Bachelor
# 3                3.0          PhD
# 4                1.0  High School
# 5                0.0     Bachelor
# 6                2.0       Master
# 7                1.0  High School
# 8                2.0       Master
# 9                2.0       Master
